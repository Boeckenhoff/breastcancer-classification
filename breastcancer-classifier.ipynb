# %%
PROJECT_PATH = '/content/gdrive/MyDrive/CI Final Project'
DATASET_PATH = f'{PROJECT_PATH}/ICAR 2018 BACH Dataset'
# Out:
# The kernel failed to start as the module 'AsyncGenerator' could not be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
#
# <a href='https://aka.ms/kernelFailuresModuleImportErr'>Learn more</a>

# %%
import os
import glob

import random
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import torch.nn.functional as F
import torchvision 
from torchvision import *
import torchvision.transforms as transforms

from numpy import genfromtxt
from PIL import Image, ImageEnhance

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix
# Out:
# The kernel failed to start as the module 'AsyncGenerator' could not be imported.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
#
# <a href='https://aka.ms/kernelFailuresModuleImportErr'>Learn more</a>

# %% [markdown]
# # Dataset and Dataloaders

# %%
LABELS = ['Normal', 'Benign', 'InSitu', 'Invasive']
IMAGE_SIZE = (2048, 1536)
PATCH_SIZE = 512
PROJECT_PATH = '/content/gdrive/MyDrive/CI Final Project'
DATASET_PATH = f'{PROJECT_PATH}/ICAR 2018 BACH Dataset'
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
indexes_for_dataset = [i for i in range(400)]
TRAIN_INDEXES, TEST_INDEXES = train_test_split(indexes_for_dataset, test_size=0.1, random_state=5)

# %%
def __crop_img__(img, size, n):
    h, w, c = img.shape
    crops = []
    
    for _ in range(n):
        top = np.random.randint(low=0, high=h - size + 1)
        left = np.random.randint(low=0, high=w - size + 1)
        crop = img[top: top + size, left: left + size].copy()
        crop = np.rot90(crop, np.random.randint(low=0, high=4))
        if np.random.random() > 0.5:
            crop = np.flipud(crop)
        if np.random.random() > 0.5:
            crop = np.fliplr(crop)
        crops.append(crop)

    crops = np.stack(crops)
    return crops

# %%
class ICARDataset(Dataset):
    def __init__(self, path, rotate=False, flip=False, enhance=False, train=False):
        super().__init__()

        dataset = {name: index for index in range(len(LABELS)) for name in glob.glob(path + '/' + LABELS[index] + '/*.tif')}
        self.path = path
        self.dataset = dataset
        self.names = list(sorted(dataset.keys()))
        self.rotate = rotate
        self.flip = flip
        self.enhance = enhance
        self.train = train

        self.flip_options = [Image.FLIP_LEFT_RIGHT, Image.FLIP_TOP_BOTTOM]

    def __getitem__(self, index):

        if self.train:
          index = random.choice(TRAIN_INDEXES)
        else:
          index = random.choice(TEST_INDEXES)
          
        img_path = self.names[index]
        label = self.dataset[img_path]
        with Image.open(img_path) as img:

            # Apply flip or not
            if random.randint(0,1) == 1 and self.flip:
              flip_random_ind = random.randint(0,1)
              img = img.transpose(self.flip_options[flip_random_ind])

            if self.rotate:
              rotate_random_angle = random.randint(0,3)
              img = img.rotate(rotate_random_angle * 90)

            # Apply enhance or not
            if random.randint(0,1) == 1 and self.enhance:
              factors = np.random.uniform(.5, 1.5, 3)

              img = ImageEnhance.Color(img).enhance(factors[0])
              img = ImageEnhance.Contrast(img).enhance(factors[1])
              img = ImageEnhance.Brightness(img).enhance(factors[2])


            img = transforms.ToTensor()(img)

            crops = __crop_img__(img.permute(1,2,0).numpy(), 512, 20)
            crops = torch.from_numpy(crops).permute(0,3,1,2)
            return crops, label

    def __len__(self):
        return len(self.dataset)

# %%
# create the dataset
dataset_train = ICARDataset(DATASET_PATH, rotate=True, flip=True, enhance=True, train=True)
dataset_test = ICARDataset(DATASET_PATH, rotate=True, flip=True, enhance=True, train=False)

# create a data loader for train and test sets
train_dl = DataLoader(dataset_train, batch_size=25, shuffle=True)
test_dl = DataLoader(dataset_test, batch_size=25, shuffle=False)

# %% [markdown]
# # Feature Extraction

# %%
class Identity(torch.nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x

# %%
class BasicFeatureExtracter(nn.Module):
    def __init__(self):
        super(BasicFeatureExtracter, self).__init__()
        #Resnet50
        self.resnet50 = models.resnet50(pretrained=True)
        self.resnet50.fc = Identity()
        self.resnet50.to(device=DEVICE)
        #Inception V3
        self.inception_v3 = models.inception_v3(pretrained=True)
        self.inception_v3.fc = Identity()
        self.inception_v3.to(device=DEVICE)
        #VGG16
        self.vgg16 = models.vgg16(pretrained=True)
        self.vgg16 = self.vgg16.features
        self.vgg16.to(device=DEVICE)

    def extract_feat_per_crop(self, x):
      with torch.no_grad():
        res_feat = self.resnet50.forward(x)
        inc_v3_feat = self.inception_v3.forward(x)[0]
        vgg16_feat = self.vgg16.forward(x)
        
        avg_pool = nn.AvgPool2d(6)
        vgg16_feat = avg_pool(vgg16_feat)
        vgg16_feat = vgg16_feat.flatten(start_dim=1)

      features_concat = torch.cat((res_feat, inc_v3_feat,vgg16_feat), axis=1)
      return features_concat


    #shape = (Crops=20, x_size=450 ,y_size=450, channels=3)
    def forward(self,batch_data):
      feature_array = []

      for each_image in batch_data:
        each_image=each_image.to(device=DEVICE)
        features = self.extract_feat_per_crop(each_image)
        norm_features = torch.pow(features, 3)
        norm_features = torch.sum(norm_features, dim=0)
        norm_features = torch.div(norm_features, features.shape[0])
        norm_features = torch.pow(norm_features, 1/3)
        feature_array.append(norm_features.cpu().numpy())
      return np.array(feature_array)

basicFeatureExtracter =  BasicFeatureExtracter()

# %% [markdown]
# # Generate Data

# %%
# run this if you want to generate data

train_dataset_path = f'{PROJECT_PATH}/results_v2/train'
test_dataset_path = f'{PROJECT_PATH}/results_v2/test'

# lucia 0 berni 160 kuba 320 demetre 480
starting_index = 160

# generate train data
for i in range(160):
  print(f'Epoch: {i+1}')
  train_features, train_labels = next(iter(train_dl))
  train_labels = train_labels.numpy()
  feature_array_train = basicFeatureExtracter.forward(train_features)

  feature_csv_name = f'feature_array_{starting_index + i + 1}.csv'
  label_csv_name = f'feature_label_{starting_index + i + 1}.csv'
  np.savetxt(f'{train_dataset_path}/{feature_csv_name}', feature_array_train, delimiter=",")
  np.savetxt(f'{train_dataset_path}/{label_csv_name}', train_labels, delimiter=",")

starting_index = 0
# generate test data
for i in range(40):
  print(f'Epoch: {i+1}')
  test_features, test_labels = next(iter(test_dl))
  test_labels = test_labels.numpy()
  feature_array_train = basicFeatureExtracter.forward(test_features)

  feature_csv_name = f'feature_array_{starting_index + i + 1}.csv'
  label_csv_name = f'feature_label_{starting_index + i + 1}.csv'
  np.savetxt(f'{test_dataset_path}/{feature_csv_name}', feature_array_train, delimiter=",")
  np.savetxt(f'{test_dataset_path}/{label_csv_name}', test_labels, delimiter=",")

# %% [markdown]
# # Load Data

# %%
drive_path = f'{PROJECT_PATH}/results_v2'


X_train, X_test, y_train, y_test = None, None, None, None


# load train data
for i in range(600):
  print(f'Feautres for file {i + 1} was loaded')

  features_path = f'feature_array_{i+1}.csv'
  labels_path = f'feature_label_{i+1}.csv'
  features = genfromtxt(f'{drive_path}/train/{features_path}', delimiter=',')
  label = genfromtxt(f'{drive_path}/train/{labels_path}', delimiter=',')

  if X_train is None:
    X_train = features
    y_train = label
  else:
    X_train = np.concatenate([X_train, features])
    y_train = np.concatenate([y_train, label])



# load test data
for i in range(40):
  print(f'Feautres for file {i + 1} was loaded')

  features_path = f'feature_array_{i+1}.csv'
  labels_path = f'feature_label_{i+1}.csv'
  features = genfromtxt(f'{drive_path}/test/{features_path}', delimiter=',')
  label = genfromtxt(f'{drive_path}/test/{labels_path}', delimiter=',')

  if X_test is None:
    X_test = features
    y_test = label
  else:
    X_test = np.concatenate([X_test, features])
    y_test = np.concatenate([y_test, label])
# Out:
# Feautres for file 1 was loaded
# Feautres for file 2 was loaded
# Feautres for file 3 was loaded
# Feautres for file 4 was loaded
# Feautres for file 5 was loaded
# Feautres for file 6 was loaded
# Feautres for file 7 was loaded
# Feautres for file 8 was loaded
# Feautres for file 9 was loaded
# Feautres for file 10 was loaded
# Feautres for file 11 was loaded
# Feautres for file 12 was loaded
# Feautres for file 13 was loaded
# Feautres for file 14 was loaded
# Feautres for file 15 was loaded
# Feautres for file 16 was loaded
# Feautres for file 17 was loaded
# Feautres for file 18 was loaded
# Feautres for file 19 was loaded
# Feautres for file 20 was loaded
# Feautres for file 21 was loaded
# Feautres for file 22 was loaded
# Feautres for file 23 was loaded
# Feautres for file 24 was loaded
# Feautres for file 25 was loaded
# Feautres for file 26 was loaded
# Feautres for file 27 was loaded
# Feautres for file 28 was loaded
# Feautres for file 29 was loaded
# Feautres for file 30 was loaded
# Feautres for file 31 was loaded
# Feautres for file 32 was loaded
# Feautres for file 33 was loaded
# Feautres for file 34 was loaded
# Feautres for file 35 was loaded
# Feautres for file 36 was loaded
# Feautres for file 37 was loaded
# Feautres for file 38 was loaded
# Feautres for file 39 was loaded
# Feautres for file 40 was loaded
# Feautres for file 41 was loaded
# Feautres for file 42 was loaded
# Feautres for file 43 was loaded
# Feautres for file 44 was loaded
# Feautres for file 45 was loaded
# Feautres for file 46 was loaded
# Feautres for file 47 was loaded
# Feautres for file 48 was loaded
# Feautres for file 49 was loaded
# Feautres for file 50 was loaded
# Feautres for file 51 was loaded
# Feautres for file 52 was loaded
# Feautres for file 53 was loaded
# Feautres for file 54 was loaded
# Feautres for file 55 was loaded
# Feautres for file 56 was loaded
# Feautres for file 57 was loaded
# Feautres for file 58 was loaded
# Feautres for file 59 was loaded
# Feautres for file 60 was loaded
# Feautres for file 61 was loaded
# Feautres for file 62 was loaded
# Feautres for file 63 was loaded
# Feautres for file 64 was loaded
# Feautres for file 65 was loaded
# Feautres for file 66 was loaded
# Feautres for file 67 was loaded
# Feautres for file 68 was loaded
# Feautres for file 69 was loaded
# Feautres for file 70 was loaded
# Feautres for file 71 was loaded
# Feautres for file 72 was loaded
# Feautres for file 73 was loaded
# Feautres for file 74 was loaded
# Feautres for file 75 was loaded
# Feautres for file 76 was loaded
# Feautres for file 77 was loaded
# Feautres for file 78 was loaded
# Feautres for file 79 was loaded
# Feautres for file 80 was loaded
# Feautres for file 81 was loaded
# Feautres for file 82 was loaded
# Feautres for file 83 was loaded
# Feautres for file 84 was loaded
# Feautres for file 85 was loaded
# Feautres for file 86 was loaded
# Feautres for file 87 was loaded
# Feautres for file 88 was loaded
# Feautres for file 89 was loaded
# Feautres for file 90 was loaded
# Feautres for file 91 was loaded
# Feautres for file 92 was loaded
# Feautres for file 93 was loaded
# Feautres for file 94 was loaded
# Feautres for file 95 was loaded
# Feautres for file 96 was loaded
# Feautres for file 97 was loaded
# Feautres for file 98 was loaded
# Feautres for file 99 was loaded
# Feautres for file 100 was loaded
# Feautres for file 101 was loaded
# Feautres for file 102 was loaded
# Feautres for file 103 was loaded
# Feautres for file 104 was loaded
# Feautres for file 105 was loaded
# Feautres for file 106 was loaded
# Feautres for file 107 was loaded
# Feautres for file 108 was loaded
# Feautres for file 109 was loaded
# Feautres for file 110 was loaded
# Feautres for file 111 was loaded
# Feautres for file 112 was loaded
# Feautres for file 113 was loaded
# Feautres for file 114 was loaded
# Feautres for file 115 was loaded
# Feautres for file 116 was loaded
# Feautres for file 117 was loaded
# Feautres for file 118 was loaded
# Feautres for file 119 was loaded
# Feautres for file 120 was loaded
# Feautres for file 121 was loaded
# Feautres for file 122 was loaded
# Feautres for file 123 was loaded
# Feautres for file 124 was loaded
# Feautres for file 125 was loaded
# Feautres for file 126 was loaded
# Feautres for file 127 was loaded
# Feautres for file 128 was loaded
# Feautres for file 129 was loaded
# Feautres for file 130 was loaded
# Feautres for file 131 was loaded
# Feautres for file 132 was loaded
# Feautres for file 133 was loaded
# Feautres for file 134 was loaded
# Feautres for file 135 was loaded
# Feautres for file 136 was loaded
# Feautres for file 137 was loaded
# Feautres for file 138 was loaded
# Feautres for file 139 was loaded
# Feautres for file 140 was loaded
# Feautres for file 141 was loaded
# Feautres for file 142 was loaded
# Feautres for file 143 was loaded
# Feautres for file 144 was loaded
# Feautres for file 145 was loaded
# Feautres for file 146 was loaded
# Feautres for file 147 was loaded
# Feautres for file 148 was loaded
# Feautres for file 149 was loaded
# Feautres for file 150 was loaded
# Feautres for file 151 was loaded
# Feautres for file 152 was loaded
# Feautres for file 153 was loaded
# Feautres for file 154 was loaded
# Feautres for file 155 was loaded
# Feautres for file 156 was loaded
# Feautres for file 157 was loaded
# Feautres for file 158 was loaded
# Feautres for file 159 was loaded
# Feautres for file 160 was loaded
# Feautres for file 161 was loaded
# Feautres for file 162 was loaded
# Feautres for file 163 was loaded
# Feautres for file 164 was loaded
# Feautres for file 165 was loaded
# Feautres for file 166 was loaded
# Feautres for file 167 was loaded
# Feautres for file 168 was loaded
# Feautres for file 169 was loaded
# Feautres for file 170 was loaded
# Feautres for file 171 was loaded
# Feautres for file 172 was loaded
# Feautres for file 173 was loaded
# Feautres for file 174 was loaded
# Feautres for file 175 was loaded
# Feautres for file 176 was loaded
# Feautres for file 177 was loaded
# Feautres for file 178 was loaded
# Feautres for file 179 was loaded
# Feautres for file 180 was loaded
# Feautres for file 181 was loaded
# Feautres for file 182 was loaded
# Feautres for file 183 was loaded
# Feautres for file 184 was loaded
# Feautres for file 185 was loaded
# Feautres for file 186 was loaded
# Feautres for file 187 was loaded
# Feautres for file 188 was loaded
# Feautres for file 189 was loaded
# Feautres for file 190 was loaded
# Feautres for file 191 was loaded
# Feautres for file 192 was loaded
# Feautres for file 193 was loaded
# Feautres for file 194 was loaded
# Feautres for file 195 was loaded
# Feautres for file 196 was loaded
# Feautres for file 197 was loaded
# Feautres for file 198 was loaded
# Feautres for file 199 was loaded
# Feautres for file 200 was loaded
# Feautres for file 201 was loaded
# Feautres for file 202 was loaded
# Feautres for file 203 was loaded
# Feautres for file 204 was loaded
# Feautres for file 205 was loaded
# Feautres for file 206 was loaded
# Feautres for file 207 was loaded
# Feautres for file 208 was loaded
# Feautres for file 209 was loaded
# Feautres for file 210 was loaded
# Feautres for file 211 was loaded
# Feautres for file 212 was loaded
# Feautres for file 213 was loaded
# Feautres for file 214 was loaded
# Feautres for file 215 was loaded
# Feautres for file 216 was loaded
# Feautres for file 217 was loaded
# Feautres for file 218 was loaded
# Feautres for file 219 was loaded
# Feautres for file 220 was loaded
# Feautres for file 221 was loaded
# Feautres for file 222 was loaded
# Feautres for file 223 was loaded
# Feautres for file 224 was loaded
# Feautres for file 225 was loaded
# Feautres for file 226 was loaded
# Feautres for file 227 was loaded
# Feautres for file 228 was loaded
# Feautres for file 229 was loaded
# Feautres for file 230 was loaded
# Feautres for file 231 was loaded
# Feautres for file 232 was loaded
# Feautres for file 233 was loaded
# Feautres for file 234 was loaded
# Feautres for file 235 was loaded
# Feautres for file 236 was loaded
# Feautres for file 237 was loaded
# Feautres for file 238 was loaded
# Feautres for file 239 was loaded
# Feautres for file 240 was loaded
# Feautres for file 241 was loaded
# Feautres for file 242 was loaded
# Feautres for file 243 was loaded
# Feautres for file 244 was loaded
# Feautres for file 245 was loaded
# Feautres for file 246 was loaded
# Feautres for file 247 was loaded
# Feautres for file 248 was loaded
# Feautres for file 249 was loaded
# Feautres for file 250 was loaded
# Feautres for file 251 was loaded
# Feautres for file 252 was loaded
# Feautres for file 253 was loaded
# Feautres for file 254 was loaded
# Feautres for file 255 was loaded
# Feautres for file 256 was loaded
# Feautres for file 257 was loaded
# Feautres for file 258 was loaded
# Feautres for file 259 was loaded
# Feautres for file 260 was loaded
# Feautres for file 261 was loaded
# Feautres for file 262 was loaded
# Feautres for file 263 was loaded
# Feautres for file 264 was loaded
# Feautres for file 265 was loaded
# Feautres for file 266 was loaded
# Feautres for file 267 was loaded
# Feautres for file 268 was loaded
# Feautres for file 269 was loaded
# Feautres for file 270 was loaded
# Feautres for file 271 was loaded
# Feautres for file 272 was loaded
# Feautres for file 273 was loaded
# Feautres for file 274 was loaded
# Feautres for file 275 was loaded
# Feautres for file 276 was loaded
# Feautres for file 277 was loaded
# Feautres for file 278 was loaded
# Feautres for file 279 was loaded
# Feautres for file 280 was loaded
# Feautres for file 281 was loaded
# Feautres for file 282 was loaded
# Feautres for file 283 was loaded
# Feautres for file 284 was loaded
# Feautres for file 285 was loaded
# Feautres for file 286 was loaded
# Feautres for file 287 was loaded
# Feautres for file 288 was loaded
# Feautres for file 289 was loaded
# Feautres for file 290 was loaded
# Feautres for file 291 was loaded
# Feautres for file 292 was loaded
# Feautres for file 293 was loaded
# Feautres for file 294 was loaded
# Feautres for file 295 was loaded
# Feautres for file 296 was loaded
# Feautres for file 297 was loaded
# Feautres for file 298 was loaded
# Feautres for file 299 was loaded
# Feautres for file 300 was loaded
# Feautres for file 301 was loaded
# Feautres for file 302 was loaded
# Feautres for file 303 was loaded
# Feautres for file 304 was loaded
# Feautres for file 305 was loaded
# Feautres for file 306 was loaded
# Feautres for file 307 was loaded
# Feautres for file 308 was loaded
# Feautres for file 309 was loaded
# Feautres for file 310 was loaded
# Feautres for file 311 was loaded
# Feautres for file 312 was loaded
# Feautres for file 313 was loaded
# Feautres for file 314 was loaded
# Feautres for file 315 was loaded
# Feautres for file 316 was loaded
# Feautres for file 317 was loaded
# Feautres for file 318 was loaded
# Feautres for file 319 was loaded
# Feautres for file 320 was loaded
# Feautres for file 321 was loaded
# Feautres for file 322 was loaded
# Feautres for file 323 was loaded
# Feautres for file 324 was loaded
# Feautres for file 325 was loaded
# Feautres for file 326 was loaded
# Feautres for file 327 was loaded
# Feautres for file 328 was loaded
# Feautres for file 329 was loaded
# Feautres for file 330 was loaded
# Feautres for file 331 was loaded
# Feautres for file 332 was loaded
# Feautres for file 333 was loaded
# Feautres for file 334 was loaded
# Feautres for file 335 was loaded
# Feautres for file 336 was loaded
# Feautres for file 337 was loaded
# Feautres for file 338 was loaded
# Feautres for file 339 was loaded
# Feautres for file 340 was loaded
# Feautres for file 341 was loaded
# Feautres for file 342 was loaded
# Feautres for file 343 was loaded
# Feautres for file 344 was loaded
# Feautres for file 345 was loaded
# Feautres for file 346 was loaded
# Feautres for file 347 was loaded
# Feautres for file 348 was loaded
# Feautres for file 349 was loaded
# Feautres for file 350 was loaded
# Feautres for file 351 was loaded
# Feautres for file 352 was loaded
# Feautres for file 353 was loaded
# Feautres for file 354 was loaded
# Feautres for file 355 was loaded
# Feautres for file 356 was loaded
# Feautres for file 357 was loaded
# Feautres for file 358 was loaded
# Feautres for file 359 was loaded
# Feautres for file 360 was loaded
# Feautres for file 361 was loaded
# Feautres for file 362 was loaded
# Feautres for file 363 was loaded
# Feautres for file 364 was loaded
# Feautres for file 365 was loaded
# Feautres for file 366 was loaded
# Feautres for file 367 was loaded
# Feautres for file 368 was loaded
# Feautres for file 369 was loaded
# Feautres for file 370 was loaded
# Feautres for file 371 was loaded
# Feautres for file 372 was loaded
# Feautres for file 373 was loaded
# Feautres for file 374 was loaded
# Feautres for file 375 was loaded
# Feautres for file 376 was loaded
# Feautres for file 377 was loaded
# Feautres for file 378 was loaded
# Feautres for file 379 was loaded
# Feautres for file 380 was loaded
# Feautres for file 381 was loaded
# Feautres for file 382 was loaded
# Feautres for file 383 was loaded
# Feautres for file 384 was loaded
# Feautres for file 385 was loaded
# Feautres for file 386 was loaded
# Feautres for file 387 was loaded
# Feautres for file 388 was loaded
# Feautres for file 389 was loaded
# Feautres for file 390 was loaded
# Feautres for file 391 was loaded
# Feautres for file 392 was loaded
# Feautres for file 393 was loaded
# Feautres for file 394 was loaded
# Feautres for file 395 was loaded
# Feautres for file 396 was loaded
# Feautres for file 397 was loaded
# Feautres for file 398 was loaded
# Feautres for file 399 was loaded
# Feautres for file 400 was loaded
# Feautres for file 401 was loaded
# Feautres for file 402 was loaded
# Feautres for file 403 was loaded
# Feautres for file 404 was loaded
# Feautres for file 405 was loaded
# Feautres for file 406 was loaded
# Feautres for file 407 was loaded
# Feautres for file 408 was loaded
# Feautres for file 409 was loaded
# Feautres for file 410 was loaded
# Feautres for file 411 was loaded
# Feautres for file 412 was loaded
# Feautres for file 413 was loaded
# Feautres for file 414 was loaded
# Feautres for file 415 was loaded
# Feautres for file 416 was loaded
# Feautres for file 417 was loaded
# Feautres for file 418 was loaded
# Feautres for file 419 was loaded
# Feautres for file 420 was loaded
# Feautres for file 421 was loaded
# Feautres for file 422 was loaded
# Feautres for file 423 was loaded
# Feautres for file 424 was loaded
# Feautres for file 425 was loaded
# Feautres for file 426 was loaded
# Feautres for file 427 was loaded
# Feautres for file 428 was loaded
# Feautres for file 429 was loaded
# Feautres for file 430 was loaded
# Feautres for file 431 was loaded
# Feautres for file 432 was loaded
# Feautres for file 433 was loaded
# Feautres for file 434 was loaded
# Feautres for file 435 was loaded
# Feautres for file 436 was loaded
# Feautres for file 437 was loaded
# Feautres for file 438 was loaded
# Feautres for file 439 was loaded
# Feautres for file 440 was loaded
# Feautres for file 441 was loaded
# Feautres for file 442 was loaded
# Feautres for file 443 was loaded
# Feautres for file 444 was loaded
# Feautres for file 445 was loaded
# Feautres for file 446 was loaded
# Feautres for file 447 was loaded
# Feautres for file 448 was loaded
# Feautres for file 449 was loaded
# Feautres for file 450 was loaded
# Feautres for file 451 was loaded
# Feautres for file 452 was loaded
# Feautres for file 453 was loaded
# Feautres for file 454 was loaded
# Feautres for file 455 was loaded
# Feautres for file 456 was loaded
# Feautres for file 457 was loaded
# Feautres for file 458 was loaded
# Feautres for file 459 was loaded
# Feautres for file 460 was loaded
# Feautres for file 461 was loaded
# Feautres for file 462 was loaded
# Feautres for file 463 was loaded
# Feautres for file 464 was loaded
# Feautres for file 465 was loaded
# Feautres for file 466 was loaded
# Feautres for file 467 was loaded
# Feautres for file 468 was loaded
# Feautres for file 469 was loaded
# Feautres for file 470 was loaded
# Feautres for file 471 was loaded
# Feautres for file 472 was loaded
# Feautres for file 473 was loaded
# Feautres for file 474 was loaded
# Feautres for file 475 was loaded
# Feautres for file 476 was loaded
# Feautres for file 477 was loaded
# Feautres for file 478 was loaded
# Feautres for file 479 was loaded
# Feautres for file 480 was loaded
# Feautres for file 481 was loaded
# Feautres for file 482 was loaded
# Feautres for file 483 was loaded
# Feautres for file 484 was loaded
# Feautres for file 485 was loaded
# Feautres for file 486 was loaded
# Feautres for file 487 was loaded
# Feautres for file 488 was loaded
# Feautres for file 489 was loaded
# Feautres for file 490 was loaded
# Feautres for file 491 was loaded
# Feautres for file 492 was loaded
# Feautres for file 493 was loaded
# Feautres for file 494 was loaded
# Feautres for file 495 was loaded
# Feautres for file 496 was loaded
# Feautres for file 497 was loaded
# Feautres for file 498 was loaded
# Feautres for file 499 was loaded
# Feautres for file 500 was loaded
# Feautres for file 501 was loaded
# Feautres for file 502 was loaded
# Feautres for file 503 was loaded
# Feautres for file 504 was loaded
# Feautres for file 505 was loaded
# Feautres for file 506 was loaded
# Feautres for file 507 was loaded
# Feautres for file 508 was loaded
# Feautres for file 509 was loaded
# Feautres for file 510 was loaded
# Feautres for file 511 was loaded
# Feautres for file 512 was loaded
# Feautres for file 513 was loaded
# Feautres for file 514 was loaded
# Feautres for file 515 was loaded
# Feautres for file 516 was loaded
# Feautres for file 517 was loaded
# Feautres for file 518 was loaded
# Feautres for file 519 was loaded
# Feautres for file 520 was loaded
# Feautres for file 521 was loaded
# Feautres for file 522 was loaded
# Feautres for file 523 was loaded
# Feautres for file 524 was loaded
# Feautres for file 525 was loaded
# Feautres for file 526 was loaded
# Feautres for file 527 was loaded
# Feautres for file 528 was loaded
# Feautres for file 529 was loaded
# Feautres for file 530 was loaded
# Feautres for file 531 was loaded
# Feautres for file 532 was loaded
# Feautres for file 533 was loaded
# Feautres for file 534 was loaded
# Feautres for file 535 was loaded
# Feautres for file 536 was loaded
# Feautres for file 537 was loaded
# Feautres for file 538 was loaded
# Feautres for file 539 was loaded
# Feautres for file 540 was loaded
# Feautres for file 541 was loaded
# Feautres for file 542 was loaded
# Feautres for file 543 was loaded
# Feautres for file 544 was loaded
# Feautres for file 545 was loaded
# Feautres for file 546 was loaded
# Feautres for file 547 was loaded
# Feautres for file 548 was loaded
# Feautres for file 549 was loaded
# Feautres for file 550 was loaded
# Feautres for file 551 was loaded
# Feautres for file 552 was loaded
# Feautres for file 553 was loaded
# Feautres for file 554 was loaded
# Feautres for file 555 was loaded
# Feautres for file 556 was loaded
# Feautres for file 557 was loaded
# Feautres for file 558 was loaded
# Feautres for file 559 was loaded
# Feautres for file 560 was loaded
# Feautres for file 561 was loaded
# Feautres for file 562 was loaded
# Feautres for file 563 was loaded
# Feautres for file 564 was loaded
# Feautres for file 565 was loaded
# Feautres for file 566 was loaded
# Feautres for file 567 was loaded
# Feautres for file 568 was loaded
# Feautres for file 569 was loaded
# Feautres for file 570 was loaded
# Feautres for file 571 was loaded
# Feautres for file 572 was loaded
# Feautres for file 573 was loaded
# Feautres for file 574 was loaded
# Feautres for file 575 was loaded
# Feautres for file 576 was loaded
# Feautres for file 577 was loaded
# Feautres for file 578 was loaded
# Feautres for file 579 was loaded
# Feautres for file 580 was loaded
# Feautres for file 581 was loaded
# Feautres for file 582 was loaded
# Feautres for file 583 was loaded
# Feautres for file 584 was loaded
# Feautres for file 585 was loaded
# Feautres for file 586 was loaded
# Feautres for file 587 was loaded
# Feautres for file 588 was loaded
# Feautres for file 589 was loaded
# Feautres for file 590 was loaded
# Feautres for file 591 was loaded
# Feautres for file 592 was loaded
# Feautres for file 593 was loaded
# Feautres for file 594 was loaded
# Feautres for file 595 was loaded
# Feautres for file 596 was loaded
# Feautres for file 597 was loaded
# Feautres for file 598 was loaded
# Feautres for file 599 was loaded
# Feautres for file 600 was loaded
# Feautres for file 1 was loaded
# Feautres for file 2 was loaded
# Feautres for file 3 was loaded
# Feautres for file 4 was loaded
# Feautres for file 5 was loaded
# Feautres for file 6 was loaded
# Feautres for file 7 was loaded
# Feautres for file 8 was loaded
# Feautres for file 9 was loaded
# Feautres for file 10 was loaded
# Feautres for file 11 was loaded
# Feautres for file 12 was loaded
# Feautres for file 13 was loaded
# Feautres for file 14 was loaded
# Feautres for file 15 was loaded
# Feautres for file 16 was loaded
# Feautres for file 17 was loaded
# Feautres for file 18 was loaded
# Feautres for file 19 was loaded
# Feautres for file 20 was loaded
# Feautres for file 21 was loaded
# Feautres for file 22 was loaded
# Feautres for file 23 was loaded
# Feautres for file 24 was loaded
# Feautres for file 25 was loaded
# Feautres for file 26 was loaded
# Feautres for file 27 was loaded
# Feautres for file 28 was loaded
# Feautres for file 29 was loaded
# Feautres for file 30 was loaded
# Feautres for file 31 was loaded
# Feautres for file 32 was loaded
# Feautres for file 33 was loaded
# Feautres for file 34 was loaded
# Feautres for file 35 was loaded
# Feautres for file 36 was loaded
# Feautres for file 37 was loaded
# Feautres for file 38 was loaded
# Feautres for file 39 was loaded
# Feautres for file 40 was loaded

# %%
print(f'Training Dataset Size: {len(X_train)}')
print(f'Test Dataset Size: {len(X_test)}')
# Out:
# Training Dataset Size: 15000
# Test Dataset Size: 1000

# %%
X_train.shape
# Out:
# (15000, 6144)

# %% [markdown]
# # Training and Testing the Gradient Boosting Classifier

# %%
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0, verbose=1).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.1397          107.10m
#          2           1.0221          104.47m
#          3           0.9415          106.14m
#          4           0.8762          104.14m
#          5           0.8356          102.05m
#          6           0.7923          101.27m
#          7           0.7578           99.69m
#          8           0.7217           98.28m
#          9           0.6984           97.00m
#         10           0.6726           95.70m
#         20           0.4842           81.10m
#         30           0.3752           67.17m
#         40           0.3022           55.83m
#         50           0.2479           45.65m
#         60           0.2102           36.11m
#         70           0.1809           26.85m
#         80           0.1602           17.77m
#         90           0.1422            8.84m
#        100           0.1271            0.00s
# 0.807

# %%
y_pred = clf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
# Out:
# [[283  63  21   8]
#  [ 28 160   3   7]
#  [  5  26 222  16]
#  [  0  12   4 142]]

# %%
dataset = {name: index for index in range(len(LABELS)) for name in glob.glob(DATASET_PATH + '/' + LABELS[index] + '/*.tif')}
labels = []
feature_array = []
for img_inx in TEST_INDEXES:
  img_path = list(dataset.keys())[img_inx]
  label = dataset[img_path]
  labels.append(label)
  with Image.open(img_path) as img:
      img = transforms.ToTensor()(img)
      img = img.to(device=DEVICE)

      crops = __crop_img__(img.permute(1,2,0).numpy(), 512, 20)
      feature_array.append(crops)
labels = np.array(labels)
feature_array = torch.from_numpy(np.array(feature_array)).permute(0,1,4,2,3)
print(f'Shape of feature array: {feature_array.shape}')
print(f'Shape of labels: {labels.shape}')
original_image_features = basicFeatureExtracter.forward(feature_array)
# Out:
# Shape of feature array: torch.Size([40, 20, 3, 512, 512])
# Shape of labels: (40,)

# %%
clf.score(original_image_features, labels)
# Out:
# 0.925

# %%
y_pred_org = clf.predict(original_image_features)
print(confusion_matrix(labels, y_pred_org))
# Out:
# [[ 5  2  1  0]
#  [ 0 10  0  0]
#  [ 0  0  7  0]
#  [ 0  0  0 15]]
